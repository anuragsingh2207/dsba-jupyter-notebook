# %% [markdown]
# <h1 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home"> Business Toolkit -Python-  End Sem Exam - Total - 60 Marks</h1>

# %% [markdown]
# <h3 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home"> SECTION A - 20 marks</h3>
#
# >#### Each question carries 2 marks
#
# >#### 1. a)What are the differences between the lambda and def with respect to Python functions?
# >#### 1. b)What are some of the advantages of using list comprehensions? (Write at least 2)
# >#### 1. c)Explain the "Break" statement with examples.
# >#### 1. d)What is Boolean in python?
# >#### 1. e)Explain negative indexing in python with example.

# %% [markdown]
# >#### 2.a)What is the use of Shape() function in Numpy array?
# >#### 2.b)What is the difference in Pandas series and Numpy array?
# >#### 2.c)Define the different ways in which a DataFrame can be created in pandas?
# >#### 2.d)Which function can be used to remove a column from DataFrame?
# >#### 2.e)How to Rename the Index or Columns of a Pandas DataFrame?

# %% [markdown]
# >#### 1. a) What are the differences between the lambda and def with respect to Python functions?

# %% [markdown]
# >#### 1. b)What are some of the advantages of using list comprehensions? (Write at least 2)

# %% [markdown]
# >#### 1. c)Explain the "Break" statement with examples.

# %% [markdown]
# >#### 1. e)Explain negative indexing in python with example

# %% [markdown]
# >#### 1. d)What is Boolean in python?

# %% [markdown]
# >#### 2.a)What is the use of Shape() function in Numpy array?

# %% [markdown]
# >#### 2.b)What is the difference in Pandas series and Numpy array

# %% [markdown]
# >#### 2.c)Define the different ways in which a DataFrame can be created in pandas?

# %% [markdown]
# >#### 2.d)Which function can be used to remove a column from DataFrame?

# %% [markdown]
# >#### 2.e)How to Rename the Index or Columns of a Pandas DataFrame?

# %% [markdown]
# <h3 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home"> SECTION B  - 20 Marks</h3>
#
# >#### 3a) Using the list of tree names = ["Mango tree", "Coconut tree", "papaya tree" , "Apple tree", "Banana tree", "Blackberry tree"] answer the below questions
#
# Step1: Using tree names remove items at indexes [2,3,4] by replacing with an empty list.(2 Mark)
#
# Step2: Add the items[Neem Tree, Peepal Tree] starting at index [3]. (3 Mark)
#
# Step3: Write a function determine how many times a given letter "n" occurs in a string= (" Banana tree") (5 Marks)
#
# ##### Sample Output
#
# Step1: ['Mango tree', 'Coconut tree', 'Blackberry tree']
#
#
# Step2: ['Mango tree', 'Coconut tree', 'Banana tree', 'Neem Tree', ' Peepal Tree', 'Blackberry tree']
#
#
# Step3:
#
# Letter:n
#
# Count is:
#
# 2
#
#
#
#
# >#### 3b)
#
# #### i). One way to solve math equations is by trial and error. Computers can help with that. The equation $21x^2- x^3 + 21904 = 0$ has an integer solution between 1 and 100. Print that x value which satisfies this equation (5 Marks)
#
#
# #### ii). Write a program that asks the user to enter a string of at least six characters. Then print out the following: (5 Marks)
#
# (a) Every character of the string except the last one
#
# (b) Every character of the string except the first and last
#
# (c) If the string contains a lowercase letter 'a', print out the index of the first 'a'. Otherwise print that there is no lowercase letter 'a'
#
# (d) The string in all caps
#
# (e) The string with every space replaced with an underscore
#
#
# ***
# #### Sample Input/Output:
#
# Enter a string: ABCDE aGHI
#
# a. Every character of the string except the last one:  ABCDE aGH
#
# b. Every character of the string except the first and last:  BCDE aGH
#
# c. Index of the first a :  6
#
# d. The string in all caps:  ABCDE AGHI
#
# e. The string with every space replaced with an underscore:  ABCDE_aGHI
#
#
# ***

# %% [markdown]
# >#### 3a) Using the list of tree names = ["Mango tree", "Coconut tree", "papaya tree" , "Apple tree", "Banana tree", "Blackberry tree"] answer the below questions
#
# Step1: Using tree names remove items at indexes [2,3,4] by replacing with an empty list.(2 Mark)
#
# Step2: Add the items[Neem Tree, Peepal Tree] starting at index [3]. (3 Mark)
#
# Step3: Write a function determine how many times a given letter is "n" occurs in a string= (" Banana tree") (5 Marks)

# %% [markdown]
# ##### Sample Output
#
# Step1: ['Mango tree', 'Coconut tree', 'Blackberry tree']
#
#
# Step2: ['Mango tree', 'Coconut tree', 'Banana tree', 'Neem Tree', ' Peepal Tree', 'Blackberry tree']
#
#
# Step3:
#
# Letter:n
#
# Count is:
#
# 2

# %%
tree_names = ["Mango tree", "Coconut tree", "papaya tree" , "Apple tree", "Banana tree", "Blackberry tree"]
tree_names
# Out:
# ['Mango tree',
#  'Coconut tree',
#  'papaya tree',
#  'Apple tree',
#  'Banana tree',
#  'Blackberry tree']

# %% [markdown]
# #####  Step1 : Remove the tree names at indexs [2,3,4] by replacing with an empty list (2 Mark)

# %%
tree_names[2:5]=[]
tree_names
# Out:
# ['Mango tree', 'Coconut tree', 'Blackberry tree']

# %% [markdown]
# ##### Step2: Add the items[Neem Tree, Peepal Tree] starting at index 3 by replacing an empty slice with non-empty list. (3 Mark)

# %%
tree_names[3:5]=['Neem tree','peepal tree']
tree_names
# Out:
# ['Mango tree', 'Coconut tree', 'Blackberry tree', 'Neem tree', 'peepal tree']

# %% [markdown]
# ##### Step3:  Write a function to determine how many times a given letter "n" occurs in a string= (" Banana tree") (5 Marks)

# %%
def count_letter_occ(input_string,target_letter):
    count=input_string.count(target_letter)
    return count
input_string = 'banana'
target_letter = 'n'
a = count_letter_occ(input_string,target_letter)
a
# Out:
# 2

# %% [markdown]
# >#### 3b)

# %% [markdown]
# #### i). One way to solve math equations is by trial and error. Computers can help with that. The equation $21x^2- x^3 + 21904 = 0$ has an integer solution between 1 and 100. Print that x value which satisfies this equation (5 Marks)

# %%
for x in range(1,101):
    eq=21*x**2 -x**3 +21904
    if eq==0:
        print(x)
# Out:
# 37

# %% [markdown]
# #### ii). Write a program that asks the user to enter a string of at least six characters. Then print out the following: (5 Marks)
#
# (a) Every character of the string except the last one
#
# (b) Every character of the string except the first and last
#
# (c) If the string contains a lowercase letter 'a', print out the index of the first a. Otherwise print that there is no lowercase letter 'a'
#
# (d) The string in all caps
#
# (e) The string with every space replaced with an underscore
#
#
# ***
# #### Sample Input/Output:
#
# Enter a string: ABCDE aGHI
#
# a. Every character of the string except the last one:  ABCDE aGH
#
# b. Every character of the string except the first and last:  BCDE aGH
#
# c. index of the first a :  6
#
# d. The string in all caps:  ABCDE AGHI
#
# e. The string with every space replaced with an underscore:  ABCDE_aGHI
#
#
# ***

# %%
s = input('Enter a string')
if len(s)<6:
    print('Enter more than 6 letter string')
else:
    s1=s[:-1]
    print('A answer:',s1)
    s2=s[1:-1]
    print('B answer',s2)
    if 'a' in s:
        print('C answer:',s.index('a'))
    else:
        print('C answer: A does not exist')
    print('D answer:',s.upper())
    print('E answer:',s.replace(' ','_'))
# Out:
# Enter a stringABCDE aGHI
# A answer: ABCDE aGH
# B answer BCDE aGH
# C answer: 6
# D answer: ABCDE AGHI
# E answer: ABCDE_aGHI

# %% [markdown]
# <h3 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home">SECTION C (Case Study/Coding) - 20 Marks</h3>
#
# >#### Each Question carries 15 marks
#
#
#
#
#
# >### We combined Two datasets in single CSV file and mention below columns belongs to
#
#
#
#
# >### **kc_house_data_mini**
#
# The dataset consists of house prices from King County an area in the US State of Washington, this data also covers Seattle
#
#
#
#
# * id
# * date
# * price
# * bedrooms
# * bathrooms
# * sqft_living
# * sqft_lot
# * sqft_above
# * sqft_basement
# * yr_built
# * yr_renovated
#
# >###  blockbusters
#
# The highest grossing movies of each year are not necessarily the best movies of that year. And more often than not, the ones scooping up all the awards don't end up as the highest grossing ones or box-office hits.
#
# * Main_Genre - The most relevant genre of the film.
# * Genre_2 - The most relevant sub-genre of the film.
# * Genre_3 - The lesser relevant sub-genre of the film.
# * imdb_rating - The IMDb rating of the film, scraped from the official IMDb website.
# * length - The length of the film in minutes.
# * rank_in_year - The rank of the film (1 to 10) in that year, according to higher gross.
# * rating - The maturity index of a film, namely G, PG, PG-13 and R, given by Motion Picture Association of America.
# * studio - The studio house that distributes the film worldwide. While cleaning the data, I replaced every studio name with its * parent studio to avoid sparsity. All the studios which are not present now, or have been bought by other studios, are also * replaced.
# * title - Obviously, the name of the film.
# * worldwide_gross - The total gross of the film, Domestic and Worldwide, in dollars, from Box Office Mojo.
# * year - The year of release for the film.
#
#
#
# >####  4a) Read the Dataset 'kc_house_data_mini.csv' and answer the following questions.
#
# A. Convert date column in datetime object (1 Mark)
#
# B. Create a new column for Apartment_age in years of an apartment as difference between the year in which apartment is built and date column in dataset. (2 Marks)
#
# C. Find out 5 most recently renovated apartments (2 Marks)
#
# D. Count the number of apartments for each bedroom’s category. Plot it using count plot. (2 Marks)
#
# E. What is mean price for the 3 Bedroom apartment with at least 3 bathrooms. (3 Marks)
#
#
#
# >#### 4b)Read the dataset blockbusters and Answer the below questions
#
# A. Identify the number of blockbuster movies under the Main Genre Comedy. (1 Mark)
#
# B. List all the names of all the blockbuster movies with imdb ratings above 8. (1 Mark)
#
# C. Display the details of all the movies which were produced by Walt Disney Pictures and suitable to be viewed by General Audiences. (3 Marks)
#
# D. Plot a bar graph to show the total worldwide gross for year. (5 Marks)

# %%
## Kindly change the below cells from markdown to code and execute it

# %% [markdown]
# import pandas as pd
#
# import csv
#
# with open("data_set.csv","r")as file:
#
# reader=csv.reader(file)
# df=pd.read_csv("data_set.csv")
#
# df.head()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("KC_BL_DATASET.csv")
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  5652600427  20150224T000000  420000         4       2.00         1700
# 1  7888000390  20140627T000000  140000         3       1.00         1060
# 2  5318101695  20150409T000000  940000         4       1.50         2430
# 3  4039000050  20140714T000000  516130         3       1.75         1510
# 4  7853230590  20141029T000000  435000         4       2.50         2190
#
#    sqft_lot  sqft_above  sqft_basement  yr_built  ...    Genre_2    Genre_3  \
# 0      6375         850            850      1950  ...  Adventure      Drama
# 1      7473        1060              0      1959  ...  Adventure     Sci-Fi
# 2      3600        2430              0      1980  ...     Action  Adventure
# 3      8250        1510              0      1962  ...  Adventure      Drama
# 4      6578        2190              0      2004  ...     Comedy        NaN
#
#   imdb_rating length  rank_in_year  rating                studio  \
# 0         7.4    135             1   PG-13  Walt Disney Pictures
# 1         8.5    156             2   PG-13  Walt Disney Pictures
# 2         7.8    118             3      PG                 Pixar
# 3         6.2    129             4   PG-13    Universal Pictures
# 4         7.8    119             5       R      20th Century Fox
#
#                             title worldwide_gross  year
# 0                   Black Panther       700059566  2018
# 1          Avengers: Infinity War       678815482  2018
# 2                   Incredibles 2       608581744  2018
# 3  Jurassic World: Fallen Kingdom       416769345  2018
# 4                      Deadpool 2       318491426  2018
#
# [5 rows x 22 columns]

# %%
kc_house_data_mini = df.iloc[:, :11]
kc_house_data_mini.head(1)
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  5652600427  20150224T000000  420000         4        2.0         1700
#
#    sqft_lot  sqft_above  sqft_basement  yr_built  yr_renovated
# 0      6375         850            850      1950             0

# %%
blockbusters = df.iloc[:, 11:]
blockbusters.head(1)
# Out:
#   Main_Genre    Genre_2 Genre_3  imdb_rating  length  rank_in_year rating  \
# 0     Action  Adventure   Drama          7.4     135             1  PG-13
#
#                  studio          title  worldwide_gross  year
# 0  Walt Disney Pictures  Black Panther        700059566  2018

# %% [markdown]
#  _________________

# %% [markdown]
# >#### 4a) Read the Dataset 'kc_house_data_mini.csv' and answer the following questions.
#
# A. Convert date column in datetime object (1 Mark)
#
# B. Create a new column for Apartment_age in years of an apartment as difference between the year in which apartment is built and date column in dataset. (2 Marks)
#
# C. Find out 5 most recently renovated apartments (2 Marks)
#
# D. Count the number of apartments for each bedroom’s category. Plot it using count plot. (2 Marks)
#
# E. What is mean price for the 3 Bedroom apartment with at least 3 bathrooms. (3 Marks)

# %%
df=kc_house_data_mini
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  5652600427  20150224T000000  420000         4       2.00         1700
# 1  7888000390  20140627T000000  140000         3       1.00         1060
# 2  5318101695  20150409T000000  940000         4       1.50         2430
# 3  4039000050  20140714T000000  516130         3       1.75         1510
# 4  7853230590  20141029T000000  435000         4       2.50         2190
#
#    sqft_lot  sqft_above  sqft_basement  yr_built  yr_renovated
# 0      6375         850            850      1950             0
# 1      7473        1060              0      1959             0
# 2      3600        2430              0      1980             0
# 3      8250        1510              0      1962             0
# 4      6578        2190              0      2004             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 437 entries, 0 to 436
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             437 non-null    int64
#  1   date           437 non-null    object
#  2   price          437 non-null    int64
#  3   bedrooms       437 non-null    int64
#  4   bathrooms      437 non-null    float64
#  5   sqft_living    437 non-null    int64
#  6   sqft_lot       437 non-null    int64
#  7   sqft_above     437 non-null    int64
#  8   sqft_basement  437 non-null    int64
#  9   yr_built       437 non-null    int64
#  10  yr_renovated   437 non-null    int64
# dtypes: float64(1), int64(9), object(1)
# memory usage: 37.7+ KB

# %% [markdown]
# ##### A.Convert  date column in datetime object (1 Mark)

# %%
df['date'] = df['date'].astype('datetime64[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 437 entries, 0 to 436
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             437 non-null    int64
#  1   date           437 non-null    datetime64[ns]
#  2   price          437 non-null    int64
#  3   bedrooms       437 non-null    int64
#  4   bathrooms      437 non-null    float64
#  5   sqft_living    437 non-null    int64
#  6   sqft_lot       437 non-null    int64
#  7   sqft_above     437 non-null    int64
#  8   sqft_basement  437 non-null    int64
#  9   yr_built       437 non-null    int64
#  10  yr_renovated   437 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(9)
# memory usage: 37.7 KB

# %%
df.head()
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  5652600427 2015-02-24  420000         4       2.00         1700      6375
# 1  7888000390 2014-06-27  140000         3       1.00         1060      7473
# 2  5318101695 2015-04-09  940000         4       1.50         2430      3600
# 3  4039000050 2014-07-14  516130         3       1.75         1510      8250
# 4  7853230590 2014-10-29  435000         4       2.50         2190      6578
#
#    sqft_above  sqft_basement  yr_built  yr_renovated
# 0         850            850      1950             0
# 1        1060              0      1959             0
# 2        2430              0      1980             0
# 3        1510              0      1962             0
# 4        2190              0      2004             0

# %% [markdown]
# ##### B Create a new column for Apartment_age in years of an apartment as difference between the year in which apartment is built and date column in dataset. (2 Marks)

# %%
df['Apartment_age'] = pd.DatetimeIndex(df['date']).year - df['yr_built']

# %%
df.head()
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  5652600427 2015-02-24  420000         4       2.00         1700      6375
# 1  7888000390 2014-06-27  140000         3       1.00         1060      7473
# 2  5318101695 2015-04-09  940000         4       1.50         2430      3600
# 3  4039000050 2014-07-14  516130         3       1.75         1510      8250
# 4  7853230590 2014-10-29  435000         4       2.50         2190      6578
#
#    sqft_above  sqft_basement  yr_built  yr_renovated  Apartment_age
# 0         850            850      1950             0             65
# 1        1060              0      1959             0             55
# 2        2430              0      1980             0             35
# 3        1510              0      1962             0             52
# 4        2190              0      2004             0             10

# %% [markdown]
# ##### C. Find out 5 most recently renovated apartments (2 Marks)

# %%
df_sort = df.sort_values(by=['yr_renovated'],ascending=False)
df_sort.head(5)
# Out:
#              id       date   price  bedrooms  bathrooms  sqft_living  \
# 111  2473100450 2014-09-09  330000         4       2.00         1590
# 214  9187200275 2015-04-20  905000         4       2.25         2240
# 432  9274201006 2014-05-07  705000         4       2.50         2650
# 140  7284900385 2014-05-21  970000         4       3.25         2790
# 141  2944500330 2014-08-25  330000         4       2.50         2510
#
#      sqft_lot  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 111      9100        1040            550      1967          2014
# 214      5000        1770            470      1900          2014
# 432      4316        1520           1130      1905          2013
# 140      5420        1130           1660      1963          2013
# 141      8580        2510              0      1991          2012
#
#      Apartment_age
# 111             47
# 214            115
# 432            109
# 140             51
# 141             23

# %% [markdown]
# ##### D.	Count the number of apartments for each bedroom’s category.
# ##### Plot it using count plot.. (2 Marks)

# %%
df.head()
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  5652600427 2015-02-24  420000         4       2.00         1700      6375
# 1  7888000390 2014-06-27  140000         3       1.00         1060      7473
# 2  5318101695 2015-04-09  940000         4       1.50         2430      3600
# 3  4039000050 2014-07-14  516130         3       1.75         1510      8250
# 4  7853230590 2014-10-29  435000         4       2.50         2190      6578
#
#    sqft_above  sqft_basement  yr_built  yr_renovated  Apartment_age
# 0         850            850      1950             0             65
# 1        1060              0      1959             0             55
# 2        2430              0      1980             0             35
# 3        1510              0      1962             0             52
# 4        2190              0      2004             0             10

# %%
a= df['bedrooms'].value_counts()
a
# Out:
# bedrooms
# 3    206
# 4    137
# 2     48
# 5     31
# 6      9
# 1      2
# 8      2
# 0      1
# 7      1
# Name: count, dtype: int64

# %%
# additional wy to answer using matplotlib using plot of kind = 'bar'
a.plot(kind='bar')
# Out:
# <Axes: xlabel='bedrooms'>

# %%
sns.countplot(x='bedrooms',data=df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='count'>

# %% [markdown]
# ##### E. What is mean price for the 3 Bedroom apartment with atleast 3 bathrooms. (3 Marks)

# %%
df.head()
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  5652600427 2015-02-24  420000         4       2.00         1700      6375
# 1  7888000390 2014-06-27  140000         3       1.00         1060      7473
# 2  5318101695 2015-04-09  940000         4       1.50         2430      3600
# 3  4039000050 2014-07-14  516130         3       1.75         1510      8250
# 4  7853230590 2014-10-29  435000         4       2.50         2190      6578
#
#    sqft_above  sqft_basement  yr_built  yr_renovated  Apartment_age
# 0         850            850      1950             0             65
# 1        1060              0      1959             0             55
# 2        2430              0      1980             0             35
# 3        1510              0      1962             0             52
# 4        2190              0      2004             0             10

# %%
df_3_aprt =df[ df['bedrooms']==3]

# %%
df_3_aprt
# Out:
#              id       date    price  bedrooms  bathrooms  sqft_living  \
# 1    7888000390 2014-06-27   140000         3       1.00         1060
# 3    4039000050 2014-07-14   516130         3       1.75         1510
# 6    1473200170 2014-07-29   305000         3       2.50         1260
# 7    3356407665 2014-09-24   180000         3       1.75         1330
# 10   2011000010 2014-05-02   257950         3       1.75         1370
# ..          ...        ...      ...       ...        ...          ...
# 423  6147600040 2015-02-24   163000         3       1.75         1290
# 431  3862710010 2015-05-01   424950         3       2.50         1650
# 433  3395040580 2014-10-23   310000         3       2.25         1590
# 434  5634500251 2015-03-27   450000         3       1.00         1160
# 436  1525059198 2014-05-21  1190000         3       2.25         2760
#
#      sqft_lot  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 1        7473        1060              0      1959             0
# 3        8250        1510              0      1962             0
# 6        1622        1260              0      2009             0
# 7       16000        1330              0      1978             0
# 10       5858        1370              0      1987             0
# ..        ...         ...            ...       ...           ...
# 423      4811        1290              0      1996             0
# 431      4777        1650              0      2013             0
# 433      3056        1590              0      2001             0
# 434     36831        1160              0      1938             0
# 436     40946        2760              0      1978             0
#
#      Apartment_age
# 1               55
# 3               52
# 6                5
# 7               36
# 10              27
# ..             ...
# 423             19
# 431              2
# 433             13
# 434             77
# 436             36
#
# [206 rows x 12 columns]

# %%
df_3_aprt_bat = df_3_aprt[df_3_aprt['bathrooms']>=3]
df_3_aprt_bat
# Out:
#              id       date    price  bedrooms  bathrooms  sqft_living  \
# 16   3616600250 2014-05-27  1600000         3       3.25         3790
# 25   1522039105 2015-01-15   729000         3       4.25         3300
# 31   4310702837 2014-12-01   375000         3       3.25         1370
# 64    820000018 2014-10-14   387500         3       3.25         1860
# 230  6362900172 2014-09-23   499950         3       3.50         1820
# 231  7852090180 2014-08-04   538500         3       3.50         2500
# 278   624110020 2014-09-25   730000         3       3.00         3460
# 310  3892500070 2014-07-28  1480000         3       3.50         4070
# 335  1225039052 2014-11-12   465000         3       3.25         1510
# 365  4221900305 2015-01-21  1310000         3       3.25         4030
#
#      sqft_lot  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 16      19000        3790              0      1985             0
# 25     308080        2520            780      1976             0
# 31       1227        1370              0      2007             0
# 64       2218        1860              0      2001             0
# 230      1991        1430            390      2014             0
# 231      4270        2500              0      2000             0
# 278     13129        2560            900      1988             0
# 310     26000        4070              0      1991             0
# 335      1850        1230            280      2001             0
# 365      6300        3630            400      2006             0
#
#      Apartment_age
# 16              29
# 25              39
# 31               7
# 64              13
# 230              0
# 231             14
# 278             26
# 310             23
# 335             13
# 365              9

# %%
df_3_aprt_bat['price'].mean()
# Out:
# 811495.0

# %%
df[(df['bedrooms']==3) & (df['bathrooms']>=3)]['price'].mean()
# Out:
# 811495.0

# %% [markdown]
# >#### 4b)Read the dataset blockbusters and Answer the below questions
#
# A.Identify the number of blockbuster movies under the Main Genre Comedy. (1 Mark)
#
# B. List all the names of all the blockbuster movies with imdb ratings above 8. (1 Mark)
#
# C. Display the details of all the movies which were produced by Walt Disney Pictures and suitable to be viewed by General Audiences. (3 Marks)
#
# D. Plot a bar graph to show the total worldwide gross for year. (5 Marks)

# %%
blockbusters.head()
# Out:
#   Main_Genre    Genre_2    Genre_3  imdb_rating  length  rank_in_year rating  \
# 0     Action  Adventure      Drama          7.4     135             1  PG-13
# 1     Action  Adventure     Sci-Fi          8.5     156             2  PG-13
# 2  Animation     Action  Adventure          7.8     118             3     PG
# 3     Action  Adventure      Drama          6.2     129             4  PG-13
# 4     Action     Comedy        NaN          7.8     119             5      R
#
#                  studio                           title  worldwide_gross  year
# 0  Walt Disney Pictures                   Black Panther        700059566  2018
# 1  Walt Disney Pictures          Avengers: Infinity War        678815482  2018
# 2                 Pixar                   Incredibles 2        608581744  2018
# 3    Universal Pictures  Jurassic World: Fallen Kingdom        416769345  2018
# 4      20th Century Fox                      Deadpool 2        318491426  2018

# %% [markdown]
# ##### A.	Identify the number of blockbuster movies under the Main Genre Comedy. (1 Mark)

# %%
comedy = blockbusters[blockbusters['Main_Genre']=='Comedy']
comedy
# Out:
#     Main_Genre    Genre_2    Genre_3  imdb_rating  length  rank_in_year  \
# 50      Comedy  Animation  Adventure          7.7     102             1
# 56      Comedy  Animation  Adventure          7.4     104             7
# 64      Comedy  Animation  Adventure          6.7      88             5
# 67      Comedy  Adventure  Animation          7.0      93             8
# 77      Comedy        NaN        NaN          6.5     102             8
# 78      Comedy  Animation  Adventure          5.5     103             9
# 79      Comedy  Animation  Adventure          6.3     106            10
# 80      Comedy  Animation  Adventure          8.4     103             1
# 84      Comedy  Animation  Adventure          6.4      93             5
# 95      Comedy  Animation  Adventure          8.3      96             6
# 99      Comedy        NaN        NaN          7.8     100            10
# 113     Comedy  Animation  Adventure          6.1      93             4
# 117     Comedy  Animation  Adventure          7.4      87             8
# 124     Comedy  Adventure     Action          6.4     108             5
# 125     Comedy  Animation  Adventure          7.2     117             6
# 135     Comedy  Animation  Adventure          6.9      86             6
# 137     Comedy  Adventure     Family          6.7     115             8
# 140     Comedy  Animation  Adventure          7.2      93             1
# 148     Comedy  Adventure  Animation          6.0      90             9
# 151     Comedy  Animation  Adventure          8.2     100             2
# 167     Comedy  Animation  Adventure          7.6      81             8
# 172     Comedy  Animation  Adventure          8.1      92             3
# 173     Comedy  Animation  Adventure          7.9      90             4
# 186     Comedy        NaN        NaN          7.0     108             7
# 192     Comedy  Animation  Adventure          7.9      92             3
# 199     Comedy  Adventure     Action          6.6      95            10
# 204     Comedy  Animation  Adventure          7.2      95             5
# 216     Comedy        NaN        NaN          6.8      86             7
# 231     Comedy  Animation  Adventure          8.3      81             2
# 246     Comedy        NaN        NaN          7.3     107             7
# 260     Comedy  Animation  Adventure          8.0      90             1
# 278     Comedy        NaN        NaN          6.7      84             9
# 279     Comedy    Western        NaN          6.7     113            10
# 288     Comedy  Adventure     Action          6.7      93             9
# 304     Comedy        NaN        NaN          5.9     107             5
# 305     Comedy  Adventure     Action          5.5     108             6
# 309     Comedy        NaN        NaN          7.4      92            10
# 316     Comedy        NaN        NaN          6.4     111             7
# 324     Comedy  Adventure     Action          7.3     119             5
# 328     Comedy  Adventure     Action          5.8      94             9
# 336     Comedy  Adventure     Action          6.0     106             7
# 339     Comedy  Adventure        NaN          6.3     102            10
# 341     Comedy     Action        NaN          7.3     105             2
# 345     Comedy        NaN        NaN          6.6      96             6
# 348     Comedy  Adventure     Action          6.9     106             9
# 353     Comedy        NaN        NaN          7.5     116             4
# 364     Comedy        NaN        NaN          6.1      94             5
# 375     Comedy     Action        NaN          6.1      95             6
# 381     Comedy        NaN        NaN          6.6     110             2
# 383     Comedy        NaN        NaN          7.8      88             4
# 384     Comedy     Action        NaN          6.0     116             5
# 397     Comedy        NaN        NaN          7.2      94             8
# 402     Comedy        NaN        NaN          7.6     109             3
# 403     Comedy     Action        NaN          6.2     114             4
# 405     Comedy     Action        NaN          6.2      99             6
#
#     rating                studio                                  title  \
# 50      PG  Walt Disney Pictures                                 Frozen
# 56       G  Walt Disney Pictures                    Monsters University
# 64      PG      20th Century Fox             Ice Age: Continental Drift
# 67      PG    Paramount Pictures     Madagascar 3: Europe's Most Wanted
# 77       R           Warner Bros                   The Hangover Part II
# 78      PG     Columbia Pictures                             The Smurfs
# 79       G  Walt Disney Pictures                                 Cars 2
# 80       G  Walt Disney Pictures                            Toy Story 3
# 84      PG    Paramount Pictures                    Shrek Forever After
# 95      PG                 Pixar                                     Up
# 99       R           Warner Bros                           The Hangover
# 113     PG            DreamWorks                        Shrek the Third
# 117  PG-13      20th Century Fox                     The Simpsons Movie
# 124     PG      20th Century Fox                    Night at the Museum
# 125      G                 Pixar                                   Cars
# 135     PG            DreamWorks                             Madagascar
# 137     PG           Warner Bros      Charlie and the Chocolate Factory
# 140     PG            DreamWorks                                Shrek 2
# 148     PG            DreamWorks                             Shark Tale
# 151      G                 Pixar                           Finding Nemo
# 167     PG      20th Century Fox                                Ice Age
# 172      G                 Pixar                         Monsters, Inc.
# 173     PG            DreamWorks                                  Shrek
# 186  PG-13    Universal Pictures                       Meet the Parents
# 192      G  Walt Disney Pictures                            Toy Story 2
# 199  PG-13           Warner Bros  Austin Powers: The Spy Who Shagged Me
# 204      G  Walt Disney Pictures                           A Bug's Life
# 216  PG-13    Universal Pictures                              Liar Liar
# 231      G  Walt Disney Pictures                              Toy Story
# 246  PG-13           Warner Bros                        Dumb and Dumber
# 260      G  Walt Disney Pictures                                Aladdin
# 278  PG-13      20th Century Fox                             Hot Shots!
# 279  PG-13     Columbia Pictures                          City Slickers
# 288     PG           Warner Bros           Teenage Mutant Ninja Turtles
# 304     PG    Universal Pictures                                  Twins
# 305     PG    Paramount Pictures                  "Crocodile" Dundee II
# 309     PG           Warner Bros                            Beetlejuice
# 316  PG-13    Universal Pictures               The Secret of My Success
# 324     PG    Paramount Pictures          Star Trek IV: The Voyage Home
# 328  PG-13    Paramount Pictures                       The Golden Child
# 336     PG      20th Century Fox                  The Jewel of the Nile
# 339     PG           Warner Bros                          Spies Like Us
# 341      R    Paramount Pictures                      Beverly Hills Cop
# 345      R           Warner Bros                         Police Academy
# 348     PG      20th Century Fox                    Romancing the Stone
# 353      R    Paramount Pictures                         Trading Places
# 364      R      20th Century Fox                                Porky's
# 375     PG      20th Century Fox                     The Cannonball Run
# 381     PG      20th Century Fox                                 9 to 5
# 383     PG    Paramount Pictures                              Airplane!
# 384     PG           Warner Bros                  Any Which Way You Can
# 397      R    Universal Pictures                               The Jerk
# 402      R    Universal Pictures        National Lampoon's Animal House
# 403     PG           Warner Bros              Every Which Way but Loose
# 405     PG           Warner Bros                                 Hooper
#
#      worldwide_gross  year
# 50        1274219009  2013
# 56         743559607  2013
# 64         877244782  2012
# 67         746921274  2012
# 77         586764305  2011
# 78         563749323  2011
# 79         559852396  2011
# 80        1063171911  2010
# 84         752600867  2010
# 95         731342744  2009
# 99         467483912  2009
# 113        798958162  2007
# 117        527071022  2007
# 124        574480052  2006
# 125        461983149  2006
# 135        532680671  2005
# 137        474968763  2005
# 140        919838758  2004
# 148        367275019  2004
# 151        867893978  2003
# 167        383257136  2002
# 172        525366597  2001
# 173        484409218  2001
# 186        330444045  2000
# 192        485015179  1999
# 199        312016858  1999
# 204        363398565  1998
# 216        302710615  1997
# 231        361958736  1995
# 246        247275374  1994
# 260        504050219  1992
# 278        181096164  1991
# 279        179033791  1991
# 288        201965915  1990
# 304        111938388  1988
# 305        109306210  1988
# 309         73707461  1988
# 316         66995000  1987
# 324        109713132  1986
# 328         79817937  1986
# 336         75973200  1985
# 339         60088980  1985
# 341        234760478  1984
# 345         81198894  1984
# 348         78371200  1984
# 353         90404800  1983
# 364        105492483  1982
# 375         72179579  1981
# 381        103290500  1980
# 383         83453539  1980
# 384         70687344  1980
# 397         73691419  1979
# 402        120091123  1978
# 403         85196485  1978
# 405         78000000  1978

# %%
blockbusters[blockbusters['Main_Genre']=='Comedy']['title'].count()
# Out:
# 55

# %%
# there are totally 55....

# %%
len(comedy)
# Out:
# 55

# %% [markdown]
# ##### B.	List all the names of all the blockbuster movies with imdb ratings above 8. (1 Mark)

# %%
blockbusters[blockbusters['imdb_rating']>8]['title']
# Out:
# 1                                 Avengers: Infinity War
# 9                                        A Star is Born
# 33                                            Inside Out
# 42                               Guardians of the Galaxy
# 45                            X-Men: Days of Future Past
# 49                                          Interstellar
# 60                                          The Avengers
# 62                                 The Dark Knight Rises
# 70         Harry Potter and the Deathly Hallows - Part 2
# 80                                           Toy Story 3
# 83                                             Inception
# 89                              How to Train Your Dragon
# 95                                                    Up
# 100                                      The Dark Knight
# 108                                               WALL-E
# 138                                        Batman Begins
# 150        The Lord of the Rings: The Return of the King
# 151                                         Finding Nemo
# 153    Pirates of the Caribbean: The Curse of the Bla...
# 160                The Lord of the Rings: The Two Towers
# 171    The Lord of the Rings: The Fellowship of the Ring
# 172                                       Monsters, Inc.
# 181                                            Gladiator
# 191                                      The Sixth Sense
# 193                                           The Matrix
# 198                                      American Beauty
# 201                                  Saving Private Ryan
# 231                                            Toy Story
# 236                                                Seven
# 240                                        The Lion King
# 241                                         Forrest Gump
# 253                                     Schindler's List
# 270                           Terminator 2: Judgment Day
# 274                             The Silence of the Lambs
# 290                   Indiana Jones and the Last Crusade
# 306                                             Die Hard
# 322                                              Platoon
# 326                                               Aliens
# 330                                   Back to the Future
# 347                                       The Terminator
# 350             Star Wars Episode VI: Return of the Jedi
# 370                              Raiders of the Lost Ark
# 380         Star Wars Episode V: The Empire Strikes Back
# 393                                       Apocalypse Now
# 395                                                Alien
# 409                                      The Deer Hunter
# 410                                            Star Wars
# 419                                           Annie Hall
# 420                                                Rocky
# 430                                    Dog Day Afternoon
# Name: title, dtype: object

# %%
blockbusters.head()
# Out:
#   Main_Genre    Genre_2    Genre_3  imdb_rating  length  rank_in_year rating  \
# 0     Action  Adventure      Drama          7.4     135             1  PG-13
# 1     Action  Adventure     Sci-Fi          8.5     156             2  PG-13
# 2  Animation     Action  Adventure          7.8     118             3     PG
# 3     Action  Adventure      Drama          6.2     129             4  PG-13
# 4     Action     Comedy        NaN          7.8     119             5      R
#
#                  studio                           title  worldwide_gross  year
# 0  Walt Disney Pictures                   Black Panther        700059566  2018
# 1  Walt Disney Pictures          Avengers: Infinity War        678815482  2018
# 2                 Pixar                   Incredibles 2        608581744  2018
# 3    Universal Pictures  Jurassic World: Fallen Kingdom        416769345  2018
# 4      20th Century Fox                      Deadpool 2        318491426  2018

# %% [markdown]
# ##### C.	Display the details of all the movies which were produced by Walt Disney Pictures and suitable to be viewed by General Audiences. (3 Marks)

# %%
blockbusters[(blockbusters['studio']=='Walt Disney Pictures') & (blockbusters['rating']=='PG')]
# Out:
#     Main_Genre    Genre_2    Genre_3  imdb_rating  length  rank_in_year  \
# 11       Music      Drama        NaN          7.2     129             2
# 21   Animation     Family        NaN          7.3     100             2
# 24      Action  Adventure     Family          7.4     111             5
# 26   Animation     Action  Adventure          8.0     108             7
# 38     Romance    Fantasy        NaN          6.9     105             9
# 43     Fantasy  Adventure     Action          7.1      97             4
# 50      Comedy  Animation  Adventure          7.7     102             1
# 81     Fantasy     Family  Adventure          6.5     108             2
# 87   Animation     Comedy  Animation          7.8     100             8
# 109     Family  Adventure     Action          6.6     150            10
# 118   Thriller  Adventure     Action          6.5     124             9
# 132    Fantasy     Family  Adventure          6.9     143             3
# 184  Animation  Animation  Adventure          6.4      82             5
# 267      Music     Comedy        NaN          6.2     100             8
# 294      Drama        NaN        NaN          8.0     128             5
# 296     Family     Comedy  Adventure          6.2      93             7
# 301      Crime     Comedy  Animation          7.7     104             2
# 310     Family      Drama     Comedy          5.8     102             1
#
#     rating                studio  \
# 11      PG  Walt Disney Pictures
# 21      PG  Walt Disney Pictures
# 24      PG  Walt Disney Pictures
# 26      PG  Walt Disney Pictures
# 38      PG  Walt Disney Pictures
# 43      PG  Walt Disney Pictures
# 50      PG  Walt Disney Pictures
# 81      PG  Walt Disney Pictures
# 87      PG  Walt Disney Pictures
# 109     PG  Walt Disney Pictures
# 118     PG  Walt Disney Pictures
# 132     PG  Walt Disney Pictures
# 184     PG  Walt Disney Pictures
# 267     PG  Walt Disney Pictures
# 294     PG  Walt Disney Pictures
# 296     PG  Walt Disney Pictures
# 301     PG  Walt Disney Pictures
# 310     PG  Walt Disney Pictures
#
#                                                  title  worldwide_gross  year
# 11                               Beauty and the Beast         504014165  2017
# 21                                        Finding Dory        486295561  2016
# 24                                    The Jungle Book         364001123  2016
# 26                                            Zootopia        341268248  2016
# 38                                          Cinderella        201151353  2015
# 43                                          Maleficent        758654942  2014
# 50                                              Frozen       1274219009  2013
# 81                                 Alice in Wonderland       1025467110  2010
# 87                                             Tangled        591794936  2010
# 109           The Chronicles of Narnia: Prince Caspian        419665568  2008
# 118                 National Treasure: Book of Secrets        457364600  2007
# 132  The Chronicles of Narnia: The Lion, the Witch ...        745011272  2005
# 184                                           Dinosaur        349822765  2000
# 267                                         Sister Act        231605150  1992
# 294                                 Dead Poets Society        235860116  1989
# 296                           Honey, I Shrunk the Kids        222724172  1989
# 301                            Who Framed Roger Rabbit        156452370  1988
# 310                               Three Men and a Baby        167780960  1987

# %% [markdown]
# ##### D. Plot a bar graph to show the total worldwide gross for year. (5 Marks)

# %%
blockbusters.head()
# Out:
#   Main_Genre    Genre_2    Genre_3  imdb_rating  length  rank_in_year rating  \
# 0     Action  Adventure      Drama          7.4     135             1  PG-13
# 1     Action  Adventure     Sci-Fi          8.5     156             2  PG-13
# 2  Animation     Action  Adventure          7.8     118             3     PG
# 3     Action  Adventure      Drama          6.2     129             4  PG-13
# 4     Action     Comedy        NaN          7.8     119             5      R
#
#                  studio                           title  worldwide_gross  year
# 0  Walt Disney Pictures                   Black Panther        700059566  2018
# 1  Walt Disney Pictures          Avengers: Infinity War        678815482  2018
# 2                 Pixar                   Incredibles 2        608581744  2018
# 3    Universal Pictures  Jurassic World: Fallen Kingdom        416769345  2018
# 4      20th Century Fox                      Deadpool 2        318491426  2018

# %%
x = blockbusters[['year','worldwide_gross']].groupby('year').sum().reset_index()['year']
y = blockbusters[['year','worldwide_gross']].groupby('year').sum().reset_index()['worldwide_gross']
plt.bar(x,y)
# Out:
# <BarContainer object of 44 artists>

# %% [markdown]
# **** All The best ****
