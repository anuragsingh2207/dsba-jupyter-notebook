# %% [markdown]
# Question 1: <br>
# Using the list of tree names = ["Mango tree", "Coconut tree", "papaya tree" , "Apple tree", "Banana tree", "Blackberry tree"] answer the below questions. <br>

# %%
tree_names = ["Mango tree", "Coconut tree", "papaya tree" , "Apple tree", "Banana tree", "Blackberry tree"]

# %% [markdown]
# Step1: Using tree names remove items at indexes [2,3,4] by replacing with an empty list.(2 Mark)

# %%
tree_names[2] = tree_names[3] = tree_names[4]= ''
print(tree_names)
# Out:
# ['Mango tree', 'Coconut tree', '', '', '', 'Blackberry tree']

# %% [markdown]
# Step2: Add the items[Neem Tree, Peepal Tree] starting at index [3]. (3 Mark)

# %%
tree_names.insert(3,"Neem Tree")
tree_names.insert(4,"Peepal Tree")
print(tree_names)
# Out:
# ['Mango tree', 'Coconut tree', '', 'Neem Tree', 'Peepal Tree', '', '', 'Blackberry tree']

# %% [markdown]
# Step3: Write a function determine how many times a given letter "n" occurs in a string= (" Banana tree") (5 Marks)

# %%
def count_num_n(input_string):
    count = 0
    for i in input_string:
        if i == 'n':
            count +=1
    return count

print("Number of 'n's in'Banana tree' are :",count_num_n(" Banana tree"))
# Out:
# Number of 'n's in'Banana tree' are : 2

# %% [markdown]
# Question 2:<br>
# One way to solve math equations is by trial and error. Computers can help with that. <br>
# The equation 21𝑥2−𝑥3+21904=0 has an integer solution between 1 and 100. <br>
#
# Print that x value which satisfies this equation (5 Marks)<br>

# %%
def math_eqn(x):
    eqn = 21*(x**2)-(x**3)+21904
    return eqn
    

for x in range(1,100):
    if math_eqn(x)==0:
        print("The value of x which satifies the equation 21𝑥2−𝑥3+21904=0 is", x)
        break
# Out:
# The value of x which satifies the equation 21𝑥2−𝑥3+21904=0 is 37

# %% [markdown]
# Question 3: <br>
# Write a program that asks the user to enter a string of at least six characters. <br>Then print out the following: (5 Marks)<br>
# (a) Every character of the string except the last one <br>
# (b) Every character of the string except the first and last <br>
# (c) If the string contains a lowercase letter ‘a’, print out the index of the first ‘a’. Otherwise print that there is no lowercase letter ‘a’. <br>
# (d) The string in all caps <br>
# (e) The string with every space replaced with an underscore ( _ ) <br>
#
#
# Sample Input/Output: <br>
# Enter a string: ABCDE aGHI <br>
#
# a. Every character of the string except the last one: ABCDE aGH <br>
# b. Every character of the string except the first and last: BCDE aGH <br>
# c. index of the first a : 6 <br>
# d. The string in all caps: ABCDE AGHI <br>
# e. The string with every space replaced with an underscore: ABCDE_aGHI <br>

# %%
input_string = input("Enter any string with atleast 6 characters: ")
# Out:
# Enter any string with atleast 6 characters:Bengaluru

# %%
print("(a)")
for i in range(0, len(input_string)-1):
    print(input_string[i])
# Out:
# Every character of the string except the last one:
# B
# e
# n
# g
# a
# l
# u
# r

# %%
print("(b)")
for i in range(1, len(input_string)-1):
    print(input_string[i])
# Out:
# Every character of the string except the first and last:
# e
# n
# g
# a
# l
# u
# r

# %%
print("(c)")
for i in range(0, len(input_string)):
    count=0
    if input_string[i]=='a':    
        print("Index of 'a' is: ",i)
        count+=1
        break
if count==0:
    print("There is no 'a' in input string")
# Out:
# Index of 'a' is:  4

# %%
print("(d)")
print(input_string.upper())
# Out:
# BENGALURU

# %%
user_input = input("Enter any string with atleast 6 characters: ")
count=0
print("(e)")
modified_string=""
for i in user_input:
    if i==' ':    
        modified_string+="_"
        count+=1
    else:
        modified_string+=i

if count==0:
    print("No spaces found in the entered string...")
else:        
    print("Modified String:",modified_string)
# Out:
# Enter any string with atleast 6 characters: Tamil Nadu
# (e)
# Modified String: Tamil_Nadu

# %% [markdown]
# Question 4: <br>
# <b> kc_house_data_mini </b> <br>
# The dataset consists of house prices from King County an area in the US State of Washington, this data also covers Seattle <br>
# a) id <br>
# b) date <br>
# c) price <br>
# d) bedrooms <br>
# e) bathrooms <br>
# f) sqft_living <br>
# g) sqft_lot <br>
# h) sqft_above <br>
# i) sqft_basement <br>
# j) yr_built <br>
#
# The dataset consists of house prices from King County an area in the US State of Washington, this data also covers Seattle <br>
# a)id <br>
# b)date <br>
# c)price <br>
# d)bedrooms <br>
# e)bathrooms <br>
# f)sqft_living <br>
# g)sqft_lot <br>
# h)sqft_above <br>
# i)sqft_basement <br>
# j)yr_built <br>
# k)yr_renovated <br>

# %% [markdown]
#   Read the Dataset 'kc_house_data_mini.csv' and answer the following questions. <br>
#
# A. Convert date column to datetime object (1 Mark)<br>
# B. Create a new column for Apartment_age in years of an apartment as difference between the year in which apartment is built and date column in dataset. (2 Marks) <br>
# C. Find out 5 most recently renovated apartments (2 Marks) <br>
# D. Count the number of apartments for each bedroom’s category. Plot it using count plot. (2 Marks) <br>
# E. What is mean price for the 3 Bedroom apartment with at least 3 bathrooms. (3 Marks) <br>

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load Dataset
df=pd.read_csv("./Dataset/kc_house_data.csv")

# %%
#Check Column
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.i
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21611 non-null  float64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# A. Convert date column to datetime object (1 Mark)

# %%
df['date'] = df.da`

# %%
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %% [markdown]
# B. Create a new column for Apartment_age in years of an apartment as difference between the year in which apartment is built and date column in dataset. (2 Marks)

# %%
df['year']= df['date'].dt.year
df['Apartment_age']= df['year']-df['yr_built']

# %%
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 0      5650     1.0           0     0  ...              0      1955
# 1      7242     2.0           0     0  ...            400      1951
# 2     10000     1.0           0     0  ...              0      1933
# 3      5000     1.0           0     0  ...            910      1965
# 4      8080     1.0           0     0  ...              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  year  \
# ...

# %% [markdown]
# C. Find out 5 most recently renovated apartments (2 Marks)

# %%
df.sort_values(by='yr_renovated').tail(5)
# Out:
#                id  date_time     price  bedrooms  bathrooms  sqft_living  \
# 14859  3585900665 2014-06-06  805000.0         5       2.50         4600
# 5683   2202500255 2015-03-05  335000.0         3       2.00         1210
# 11633   461004730 2015-04-06  717000.0         3       1.00         1150
# 13216   822069029 2015-02-17  579000.0         3       2.75         2660
# 18575  8935100100 2014-07-01  476000.0         4       3.00         2890
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 14859     19831     1.0           0     3  ...      9      2300.0
# 5683       9926     1.0           0     0  ...      7      1210.0
# 11633      5000     1.0           0     0  ...      8      1150.0
# 13216    223027     1.0           0     0  ...      8      1330.0
# 18575      6885     1.0           0     0  ...      7      1590.0
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %% [markdown]
# D. Count the number of apartments for each bedroom’s category. Plot it using count plot. (2 Marks)

# %%
df.groupby('bedrooms').count()
# Out:
#             id  date  price  bathrooms  sqft_living  sqft_lot  floors  \
# bedrooms
# 0           13    13     13         13           13        13      13
# 1          199   199    199        199          199       199     199
# 2         2760  2760   2760       2760         2760      2760    2760
# 3         9824  9824   9824       9824         9824      9824    9824
# 4         6882  6882   6882       6882         6882      6882    6882
# 5         1601  1601   1601       1601         1601      1601    1601
# 6          272   272    272        272          272       272     272
# 7           38    38     38         38           38        38      38
# 8           13    13     13         13           13        13      13
# 9            6     6      6          6            6         6       6
# 10           3     3      3          3            3         3       3
# 11           1     1      1          1            1         1       1
# ...

# %%
sns.countplot(data=df, x=df['bedrooms'])
# Out:
# <Axes: xlabel='bedrooms', ylabel='count'>

# %% [markdown]
# E. What is mean price for the 3 Bedroom apartment with at least 3 bathrooms. (3 Marks)

# %%
mean_price=df[(df['bedrooms']==3) & (df['bathrooms']>=3)]['price'].mean()
print("Mean price for 3 Bedroom apartment with at least 3 bathrooms:",mean_price)
# Out:
# Mean price for 3 Bedroom apartment with at least 3 bathrooms: 778287.2060390763

# %% [markdown]
# Question 5: <br>
# Read the dataset blockbusters and answer the below questions
#
# The highest grossing movies of each year are not necessarily the best movies of that year. And more often than not, the ones scooping up all the awards don't end up as the highest grossing ones or box-office hits.
#
# * Main_Genre - The most relevant genre of the film.
# * Genre_2 - The most relevant sub-genre of the film.
# * Genre_3 - The lesser relevant sub-genre of the film.
# * imdb_rating - The IMDb rating of the film, scraped from the official IMDb website.
# * length - The length of the film in minutes.
# * rank_in_year - The rank of the film (1 to 10) in that year, according to higher gross.
# * rating - The maturity index of a film, namely G, PG, PG-13 and R, given by Motion Picture Association of America.
# * studio - The studio house that distributes the film worldwide. While cleaning the data, I replaced every studio name with its * parent studio to avoid sparsity. All the studios which are not present now, or have been bought by other studios, are also * replaced.
# * title - Obviously, the name of the film.
# * worldwide_gross - The total gross of the film, Domestic and Worldwide, in dollars, from Box Office Mojo.
# * year - The year of release for the film.
#
# A. Identify the number of blockbuster movies under the Main Genre Comedy. (1 Mark) <br>
# B. List all the names of all the blockbuster movies with imdb ratings above 8. (1 Mark)  <br>
# C. Display the details of all the movies which were produced by Walt Disney Pictures and suitable to be viewed by General Audiences. (3 Marks)  <br>
# D. Plot a bar graph to show the total worldwide gross for year. (5 Marks)  <br>

# %%
blockbuster=pd.read_csv("./Dataset/KC_BL_DATASET.csv")

# %%
blockbuster.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  5652600427  20150224T000000  420000         4       2.00         1700
# 1  7888000390  20140627T000000  140000         3       1.00         1060
# 2  5318101695  20150409T000000  940000         4       1.50         2430
# 3  4039000050  20140714T000000  516130         3       1.75         1510
# 4  7853230590  20141029T000000  435000         4       2.50         2190
#
#    sqft_lot  sqft_above  sqft_basement  yr_built  ...    Genre_2    Genre_3  \
# 0      6375         850            850      1950  ...  Adventure      Drama
# 1      7473        1060              0      1959  ...  Adventure     Sci-Fi
# 2      3600        2430              0      1980  ...     Action  Adventure
# 3      8250        1510              0      1962  ...  Adventure      Drama
# 4      6578        2190              0      2004  ...     Comedy        NaN
#
#   imdb_rating length  rank_in_year  rating                studio  \
# ...

# %%
blockbuster.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 437 entries, 0 to 436
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               437 non-null    int64
#  1   date             437 non-null    object
#  2   price            437 non-null    int64
#  3   bedrooms         437 non-null    int64
#  4   bathrooms        437 non-null    float64
#  5   sqft_living      437 non-null    int64
#  6   sqft_lot         437 non-null    int64
#  7   sqft_above       437 non-null    int64
#  8   sqft_basement    437 non-null    int64
#  9   yr_built         437 non-null    int64
#  10  yr_renovated     437 non-null    int64
#  11  Main_Genre       437 non-null    object
#  12  Genre_2          408 non-null    object
#  13  Genre_3          296 non-null    object
#  14  imdb_rating      437 non-null    float64
#  15  length           437 non-null    int64
#  16  rank_in_year     437 non-null    int64
# ...

# %%
blockbuster = blockbuster.drop(['id','date','price','bedrooms','bathrooms','sqft_living','sqft_lot','sqft_above','sqft_basement','yr_built','yr_renovated'], axis=1)

# %%
blockbuster.head()
# Out:
#   Main_Genre    Genre_2    Genre_3  imdb_rating  length  rank_in_year rating  \
# 0     Action  Adventure      Drama          7.4     135             1  PG-13
# 1     Action  Adventure     Sci-Fi          8.5     156             2  PG-13
# 2  Animation     Action  Adventure          7.8     118             3     PG
# 3     Action  Adventure      Drama          6.2     129             4  PG-13
# 4     Action     Comedy        NaN          7.8     119             5      R
#
#                  studio                           title  worldwide_gross  year
# 0  Walt Disney Pictures                   Black Panther        700059566  2018
# 1  Walt Disney Pictures          Avengers: Infinity War        678815482  2018
# 2                 Pixar                   Incredibles 2        608581744  2018
# 3    Universal Pictures  Jurassic World: Fallen Kingdom        416769345  2018
# 4      20th Century Fox                      Deadpool 2        318491426  2018

# %% [markdown]
# A. Identify the number of blockbuster movies under the Main Genre Comedy. (1 Mark) <br>

# %%
blockbuster[blockbuster['Main_Genre']=='Comedy']
# Out:
#     Main_Genre    Genre_2    Genre_3  imdb_rating  length  rank_in_year  \
# 50      Comedy  Animation  Adventure          7.7     102             1
# 56      Comedy  Animation  Adventure          7.4     104             7
# 64      Comedy  Animation  Adventure          6.7      88             5
# 67      Comedy  Adventure  Animation          7.0      93             8
# 77      Comedy        NaN        NaN          6.5     102             8
# 78      Comedy  Animation  Adventure          5.5     103             9
# 79      Comedy  Animation  Adventure          6.3     106            10
# 80      Comedy  Animation  Adventure          8.4     103             1
# 84      Comedy  Animation  Adventure          6.4      93             5
# 95      Comedy  Animation  Adventure          8.3      96             6
# 99      Comedy        NaN        NaN          7.8     100            10
# 113     Comedy  Animation  Adventure          6.1      93             4
# ...

# %% [markdown]
# B. List all the names of all the blockbuster movies with imdb ratings above 8. (1 Mark)  <br>

# %%
blockbuster[blockbuster['imdb_rating']>8]
# Out:
#     Main_Genre    Genre_2    Genre_3  imdb_rating  length  rank_in_year  \
# 1       Action  Adventure     Sci-Fi          8.5     156             2
# 9        Music      Drama        NaN          8.1     135            10
# 33   Animation     Family        NaN          8.2      94             4
# 42      Sci-Fi  Adventure     Action          8.1     121             3
# 45      Sci-Fi  Adventure     Action          8.1     131             6
# 49      Sci-Fi  Adventure        NaN          8.7     169            10
# 60      Sci-Fi  Adventure     Action          8.2     143             1
# 62    Thriller     Action        NaN          8.5     165             3
# 70    Thriller    Fantasy  Adventure          8.1     130             1
# 80      Comedy  Animation  Adventure          8.4     103             1
# 83      Sci-Fi    Mystery     Action          8.8     148             4
# 89   Animation  Animation  Adventure          8.2      98            10
# ...

# %% [markdown]
# C. Display the details of all the movies which were produced by Walt Disney Pictures and suitable to be viewed by General Audiences. (3 Marks)  <br>

# %%
blockbuster[(blockbuster['studio']=='Walt Disney Pictures') & (blockbuster['rating']=='PG')]
# Out:
#     Main_Genre    Genre_2    Genre_3  imdb_rating  length  rank_in_year  \
# 11       Music      Drama        NaN          7.2     129             2
# 21   Animation     Family        NaN          7.3     100             2
# 24      Action  Adventure     Family          7.4     111             5
# 26   Animation     Action  Adventure          8.0     108             7
# 38     Romance    Fantasy        NaN          6.9     105             9
# 43     Fantasy  Adventure     Action          7.1      97             4
# 50      Comedy  Animation  Adventure          7.7     102             1
# 81     Fantasy     Family  Adventure          6.5     108             2
# 87   Animation     Comedy  Animation          7.8     100             8
# 109     Family  Adventure     Action          6.6     150            10
# 118   Thriller  Adventure     Action          6.5     124             9
# 132    Fantasy     Family  Adventure          6.9     143             3
# ...

# %% [markdown]
# D. Plot a bar graph to show the total worldwide gross for year. (5 Marks)  <br>

# %%
data = blockbuster[['year','worldwide_gross']].groupby('year').sum().reset_index()
x = blockbuster[['year','worldwide_gross']].groupby('year').sum().reset_index()['year']
y = blockbuster[['year','worldwide_gross']].groupby('year').sum().reset_index()['worldwide_gross']


plt.bar(x,y)
# Out:
# <BarContainer object of 44 artists>
