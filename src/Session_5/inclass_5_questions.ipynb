# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="10%">
#             <img src="in_class.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Inclass-Lab  <br>(Session 5 & 6)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Table of Content
# 1. **[Reshape](#Reshape)**
# 2. **[Pivot Table](#Pivoting)**
# 3. **[Duplicate](#Duplicating)**
# 4. **[Replace](#Replacing)**
# 5. **[Index](#Indexing)**
# 6. **[Summary Statistics](#Summary_Statistics)**
# 7. **[Merge, Join, Concatenate](#merge)**
# 8. **[Plots using Library Matplotlib ](#matplotlib)**
# 9. **[Plots using Library Seaborn ](#seaborn)**
# 10. **[Plots using Library Plotly](#plotly)**

# %% [markdown]
# **Let us import the required library**

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id='Reshape'></a>
# ## 1. Reshape

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 1. Write a program to reshape the given dataframe using the melt function, considering 'Day' as the identifier variable
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Day</th>
# <th>ICICI</th>
# <th>HDFC</th>
# </tr>
# <tr>
# <td>MON</td>
# <td>1129</td>
# <td>191</td>
# </tr>
# <tr>
# <td>TUES</td>
# <td>1132</td>
# <td>192</td>
# </tr>
# <tr>
# <td>WED</td>
# <td>1134</td>
# <td>190</td>
# </tr>
# <tr>
# <td>THU</td>
# <td>1152</td>
# <td>190</td>
# </tr>
# <tr>
# <td>FRI</td>
# <td>1152</td>
# <td>188</td>
# </tr>
#
# </table>

# %%
# type your code here
data = {
    'Day':['MON', 'TUE', 'WED', 'THU', 'FRI'],
    'ICICI' : [1129, 1132, 1134, 1152, 1152],
    'HDFC' : [191, 192, 190, 190, 188]
}

df = pd.DataFrame(data)

print(df)

print("\n\n\nMelted Dataframe:\n")
melt = pd.melt(df, id_vars='Day',var_name='Bank', value_name='Amount')

print(melt)
# Out:
#    Day  ICICI  HDFC
# 0  MON   1129   191
# 1  TUE   1132   192
# 2  WED   1134   190
# 3  THU   1152   190
# 4  FRI   1152   188
#
#
#
# Melted Dataframe:
#
#    Day   Bank  Amount
# 0  MON  ICICI    1129
# 1  TUE  ICICI    1132
# 2  WED  ICICI    1134
# 3  THU  ICICI    1152
# 4  FRI  ICICI    1152
# 5  MON   HDFC     191
# 6  TUE   HDFC     192
# 7  WED   HDFC     190
# 8  THU   HDFC     190
# 9  FRI   HDFC     188

# %% [markdown]
# <a id='Pivoting'></a>
# ## 2. Pivot Table

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 2. Find the average sales for each store
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here

data = {
    'Store':['A', 'B', 'A', 'C', 'D','A','D','A','C','B'],
    'Location' : ['Mumbai', 'Pune', 'Hyderabad', 'Mumbai', 'Pune','Delhi','Hyderabad','Pune','Mumbai', 'Pune',],
    'Sales' : [40000, 45000, 5000, 90000, 89000, 87000, 85000, 78000, 89000, 70000]
}

sales_df = pd.DataFrame(data)
print("Sales Dataframe:\n",sales_df)

print("Average Sales for each store:\n",sales_df.groupby('Store')['Sales'].mean())
# Out:
# Sales Dataframe:
#    Store   Location  Sales
# 0     A     Mumbai  40000
# 1     B       Pune  45000
# 2     A  Hyderabad   5000
# 3     C     Mumbai  90000
# 4     D       Pune  89000
# 5     A      Delhi  87000
# 6     D  Hyderabad  85000
# 7     A       Pune  78000
# 8     C     Mumbai  89000
# 9     B       Pune  70000
# Average Sales for each store:
#  Store
# A    52500.0
# B    57500.0
# C    89500.0
# D    87000.0
# Name: Sales, dtype: float64

# %% [markdown]
# <a id='Duplicating'></a>
# ## 3. Duplicate

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 3. Select duplicate rows, except the last occurrence
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# <th>City</th>
# </tr>
# <tr>
# <td>John</td>
# <td>3400</td>
# <td>Sydeny</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>1600</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Texas</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>4000</td>
# <td>London</td>
# </tr>
# <tr>
# <td>Sachine</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
#
# </table>

# %%
# type your code here
person_data = {
    'Name':['John', 'Robert', 'Aadi', 'Robert', 'Robert','Robert','Aadi','Sachine'],
    'Salary' : [3400, 3000, 1600, 3000, 3000, 3000, 4000, 3000 ],
    'City' : ['Sydney', 'Chicago', 'New York', 'Chicago', 'Chicago','Texas','London','Chicago']
}

dataframe = pd.DataFrame(person_data)

print("Original DataFrame:\n", dataframe)

dataframe = pd.DataFrame(person_data)


duplicate_rows_except_last = dataframe[dataframe.duplicated(keep='last')]
print("\n\nDuplicate DataFrame except last occurence:\n",duplicate_rows_except_last)
# Out:
# Original DataFrame:
#        Name  Salary      City
# 0     John    3400    Sydney
# 1   Robert    3000   Chicago
# 2     Aadi    1600  New York
# 3   Robert    3000   Chicago
# 4   Robert    3000   Chicago
# 5   Robert    3000     Texas
# 6     Aadi    4000    London
# 7  Sachine    3000   Chicago
#
#
# Duplicate DataFrame except last occurence:
#       Name  Salary     City
# 1  Robert    3000  Chicago
# 3  Robert    3000  Chicago

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 4.  Select the duplicated rows based on the column names 'Salary' and 'City'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# <th>City</th>
# </tr>
# <tr>
# <td>John</td>
# <td>3400</td>
# <td>Sydeny</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>1600</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Texas</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>4000</td>
# <td>London</td>
# </tr>
# <tr>
# <td>Sachine</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
#
# </table>

# %%
# type your code here
duplicate_rows_salary_city = dataframe[dataframe[['Salary','City']].duplicated()]
print("\n\nDuplicate DataFrame with Salary and City:\n",duplicate_rows_salary_city)
print
# Out:
# Duplicate DataFrame with Salary and City:
#        Name  Salary     City
# 3   Robert    3000  Chicago
# 4   Robert    3000  Chicago
# 7  Sachine    3000  Chicago
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %% [markdown]
# <a id='Replacing'></a>
# ## 4. Replace

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 5.  Replace all 0's with male and all 1's with female in the gender column
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Num_Children</th>
# <th>Gender</th>
# </tr>
# <tr>
# <td>John</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>4</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Johny</td>
# <td>5</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>3</td>
# <td>1</td>
# </tr>
#
# </table>

# %%
# type your code here
gender_data = {
    'Name':['John', 'Robert', 'Johny', 'Mia'],
    'Num_Children' : [0, 4, 5, 3 ],
    'Gender' : [0, 0, 0, '1']
}

df = pd.DataFrame(gender_data)
print("Original DataFrame:\n", df)

df['Gender'] = df['Gender'].replace({0: 'Male', '1': 'Female'})  

print("Updated DataFrame:\n", df)
# Out:
# Original DataFrame:
#       Name  Num_Children Gender
# 0    John             0      0
# 1  Robert             4      0
# 2   Johny             5      0
# 3     Mia             3      1
# Updated DataFrame:
#       Name  Num_Children  Gender
# 0    John             0    Male
# 1  Robert             4    Male
# 2   Johny             5    Male
# 3     Mia             3  Female

# %% [markdown]
# <a id='Indexing'></a>
# ## 5. Index

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 6.  Set 'Name' and 'City' columns as indices for the below dataframe
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>City</th>
# <th>Sales</th>
# <th>Expenses</th>
# </tr>
# <tr>
# <td>John</td>
# <td>New York</td>
# <td>60000</td>
# <td>12000</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>Chicago</td>
# <td>42000</td>
# <td>33000</td>
# </tr>
# <tr>
# <td>Jony</td>
# <td>Texas</td>
# <td>50000</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>California</td>
# <td>24000</td>
# <td>34000</td>
# </tr>
# <tr>
# <td>Edward</td>
# <td>Sydney</td>
# <td>12000</td>
# <td>28000</td>
# </tr>
# <tr>
# <td>Thomas</td>
# <td>New York</td>
# <td>82000</td>
# <td>19000</td>
# </tr>
# <tr>
# <td>Ethan</td>
# <td>Chicago</td>
# <td>59000</td>
# <td>32000</td>
# </tr>
# <tr>
# <td>Olivia</td>
# <td>Sydeney</td>
# <td>85000</td>
# <td>10000</td>
# </tr>
# <tr>
# <td>Arun</td>
# <td>California</td>
# <td>97000</td>
# <td>49000</td>
# </tr>
# <tr>
# <td>Ankita</td>
# <td>Texas</td>
# <td>35000</td>
# <td>34000</td>
# </tr>
# <tr>
# <td>Paulo</td>
# <td>Chicago</td>
# <td>47000</td>
# <td>55000</td>
# </tr>
#
# </table>

# %%
# type your code here
data = {
    'Name':['John', 'Robert', 'Jony', 'Mia', 'Edward','Thomas','Ethan','Olivia','Arun','Ankita','Paulo'],
    'City' : ['New York','Chicago','Texas','California','Sydney', 'New York', 'Chicago', 'Sydney','California','Texas','Chicago'],
    'Sales' : [60000, 42000, 50000, 24000, 12000, 82000, 59000, 85000, 97000, 35000, 47000 ],
    'Expense' : [12000,33000,40000,34000,28000,19000,32000,10000,49000,34000,55000]
    
}

df = pd.DataFrame(data)

print("Original DataFrame:\n",df)

df = pd.DataFrame(data, index=[data['Name'],data['City']])

print("Indexed DataFrame:\n",df)
# Out:
# Original DataFrame:
#        Name        City  Sales  Expense
# 0     John    New York  60000    12000
# 1   Robert     Chicago  42000    33000
# 2     Jony       Texas  50000    40000
# 3      Mia  California  24000    34000
# 4   Edward      Sydney  12000    28000
# 5   Thomas    New York  82000    19000
# 6    Ethan     Chicago  59000    32000
# 7   Olivia      Sydney  85000    10000
# 8     Arun  California  97000    49000
# 9   Ankita       Texas  35000    34000
# 10   Paulo     Chicago  47000    55000
# Indexed DataFrame:
#                       Name        City  Sales  Expense
# John   New York      John    New York  60000    12000
# Robert Chicago     Robert     Chicago  42000    33000
# Jony   Texas         Jony       Texas  50000    40000
# Mia    California     Mia  California  24000    34000
# Edward Sydney      Edward      Sydney  12000    28000
# Thomas New York    Thomas    New York  82000    19000
# Ethan  Chicago      Ethan     Chicago  59000    32000
# Olivia Sydney      Olivia      Sydney  85000    10000
# Arun   California    Arun  California  97000    49000
# Ankita Texas       Ankita       Texas  35000    34000
# Paulo  Chicago      Paulo     Chicago  47000    55000

# %% [markdown]
# <a id='Summary_Statistics'></a>
# ## 6. Summary Statistics

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 7.  Find the descriptive statistics for the sales column of the given dataframe
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
# type your code here
data = {
    'Month':['Jan', 'Feb', 'Mar', 'Apr', 'May','June','July','Aug','Sept','Oct','Nov','Dec'],
    'Sales' : [22000, 27000, 25000, 29000, 35000, 67000, 78000, 67000, 56000, 56000, 56000, 60000],
    'Seasons' : ['Winter', 'Winter', 'Spring', 'Spring', 'Spring', 'Summer', 'Summer', 'Summer', 'Fall', 'Fall', 'Fall','Winter' ]
}

seasons_sales_df = pd.DataFrame(data)

print("Original DataFrame:\n", seasons_sales_df)

seasons_sales_df.describe()
# Out:
# Original DataFrame:
#     Month  Sales Seasons
# 0    Jan  22000  Winter
# 1    Feb  27000  Winter
# 2    Mar  25000  Spring
# 3    Apr  29000  Spring
# 4    May  35000  Spring
# 5   June  67000  Summer
# 6   July  78000  Summer
# 7    Aug  67000  Summer
# 8   Sept  56000    Fall
# 9    Oct  56000    Fall
# 10   Nov  56000    Fall
# 11   Dec  60000  Winter
#               Sales
# count     12.000000
# mean   48166.666667
# std    19385.249000
# min    22000.000000
# 25%    28500.000000
# 50%    56000.000000
# 75%    61750.000000
# max    78000.000000

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 8.  Find the median of sales for each season
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
# type your code here
seasons_sales_df['Sales'].median()
# Out:
# 56000.0

# %% [markdown]
# <a id='merge'></a>
# ## 7. Merge, Join, Concatenate

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 9. Merge the given dataframes on the column 'Brand'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>ID</th>
# <th>Brand</th>
# <th>Product</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Apple</td>
# <td>iPhone</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Canon</td>
# <td>DSLR</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Samsung</td>
# <td>SmartPhone</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Nikon</td>
# <td>DSLR</td>
# </tr>
# <td>105</td>
# <td>Sony</td>
# <td>SmartTV</td>
# </tr>
#
# </table><br>
#
# <table>
# <tr>
#     <th>ID</th>
# <th>Brand</th>
# <th>Quantity_sold</th>
# </tr>
# <tr>
#     <td>101</td>
# <td>Apple</td>
# <td>234</td>
# </tr>
# <tr>
#     <td>102</td>
# <td>Canon</td>
# <td>344</td>
# </tr>
# <tr>
#     <td>104</td>
# <td>Samsung</td>
# <td>345</td>
# </tr>
# <tr>
#     <td>103</td>
# <td>Nikon</td>
# <td>262</td>
# </tr>
#     <td>105</td>
# <td>Sony</td>
# <td>356</td>
# </tr>
# </table>

# %%
# type your code here

data1 = {
    'ID' : [101, 102, 103, 104, 105],
    'Brand':['Apple', 'Canon', 'Samsung', 'Nikon', 'Sony'],
    'Product' : ['iPhone', 'DSLR', 'Smartphone', 'DSLR', 'SmartTV']
}

data2 = {
    'ID' : [101, 102, 103, 104, 105],
    'Brand':['Apple', 'Canon', 'Samsung', 'Nikon', 'Sony'],
    'Quantity_Sold' : ['234', '344', '345', '262', '356']
}

df1 = pd.DataFrame(data1)

df2 = pd.DataFrame(data2)

merged_df = df1.merge(df2.drop(columns='ID'), on='Brand')

merged_df
# Out:
#     ID    Brand     Product Quantity_Sold
# 0  101    Apple      iPhone           234
# 1  102    Canon        DSLR           344
# 2  103  Samsung  Smartphone           345
# 3  104    Nikon        DSLR           262
# 4  105     Sony     SmartTV           356

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 10. Using the dataframes created in question 9, merge the given dataframes by 'ID' and 'Brand'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

merged_df_2_column = df1.merge(df2, on=['Brand','ID'])

merged_df_2_column
# Out:
#     ID    Brand     Product Quantity_Sold
# 0  101    Apple      iPhone           234
# 1  102    Canon        DSLR           344
# 2  103  Samsung  Smartphone           345
# 3  104    Nikon        DSLR           262
# 4  105     Sony     SmartTV           356

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 11. Using the dataframes created in question 9, perform left join to combine values in the columns 'Brand' and 'ID'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

merged_df_2_column_left_join = df1.merge(df2, how='left', on=['Brand','ID'])

merged_df_2_column_left_join
# Out:
#     ID    Brand     Product Quantity_Sold
# 0  101    Apple      iPhone           234
# 1  102    Canon        DSLR           344
# 2  103  Samsung  Smartphone           345
# 3  104    Nikon        DSLR           262
# 4  105     Sony     SmartTV           356

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 12. Using the dataframes created in question 9, perform outer join to combine values in the columns 'Brand' and 'ID'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

merged_df_2_column_outer_join = df1.merge(df2, how='outer', on=['Brand','ID'])

merged_df_2_column_outer_join
# Out:
#     ID    Brand     Product Quantity_Sold
# 0  101    Apple      iPhone           234
# 1  102    Canon        DSLR           344
# 2  103  Samsung  Smartphone           345
# 3  104    Nikon        DSLR           262
# 4  105     Sony     SmartTV           356

# %% [markdown]
# <a id='matplotlib'></a>
# ## 8. Plots using Library Matplotlib

# %% [markdown]
# ### a. Scatter Plots

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Create a bubble plot. Further use the parameter 'alpha' to adjust the transparency level. (Generate the data using random number)</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# **Note:** A bubble chart is a type of scatter plot that represents three dimensional data. The third variable is represented by the size of a point (marker).

# %%
# type your code here



random = np.random.randint(low=0, high=100, size=(20, 20))

df = pd.DataFrame(random)

X = df[1]
Y = df[3]

plt.title("Random Number Scatter Plot")
plt.scatter(X,Y, s = np.array(Y)**2, c= 'green', alpha= 0.8)

plt.show()

# %% [markdown]
# ### b. Barplots

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 14. The exports and imports (in billion dollars) is given for a country from 2001 to 2005. Draw a barplot for the data
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
#   <tr>
#   <th>Year</th>
#   <th>Import</th>
#   <th>Export</th>
#   </tr>
#   <tr>
#   <td>2001</td>
#   <td>54.4</td>
#   <td>42.5 </td>
#   </tr>
#   <tr>
#   <td>2002</td>
#   <td>53.8</td>
#   <td>44.5</td>
#   </tr>
#   <tr>
#   <td>2003</td>
#   <td>61.6</td>
#   <td>48.3</td>
#   </tr>
#   <tr>
#   <td>2004</td>
#   <td>74.15</td>
#   <td>57.24</td>
#   </tr>
#   <tr>
#   <td>2005</td>
#   <td>89.33</td>
#   <td>69.18</td>
#   </tr>
# </table>

# %%
# type your code here
data = { "Year" : [2001, 2002, 2003, 2004, 2005],
        "Import": [54.4, 53.8, 61.6, 74.15, 89.33],
        "Export": [42.5, 44.5, 48.3, 57.24, 69.18]
}

export_df = pd.DataFrame(data)

export_df.plot(x='Year', y=['Import', 'Export'], kind='bar', rot = 45)
plt.title("Import and Export (in billion dollars) across years")
plt.xlabel("Year")
plt.ylabel("Import & Export (in billion dollars)")
plt.show()

# %% [markdown]
# ### c. Pie plots

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 15. Following is the information release after the Indian budget is declared. Plot a donut chart for it
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
#   <tr>
#   <th>Income Form </th>
#   <th>Amount (in paise)</th>
#   </tr>
#   <tr>
#   <td>Corporation Tax</td>
#   <td>21</td>
#   </tr>
#   <tr>
#   <td>Income Tax</td>
#   <td>16</td>
#   </tr>
#   <tr>
#   <td>Customs</td>
#   <td>4</td>
#   </tr>
#   <tr>
#   <td>Union Excise Duties</td>
#   <td>8</td>
# </tr>
#   <tr>
#   <td>GST & Other Taxes</td>
#   <td>19</td>
# </tr>
# <tr>
#   <td>Non-Tax Revenue</td>
#   <td>9</td>
#   </tr>
#   <tr>
#   <td>Non-Debt Capital Receipts</td>
#   <td>3</td>
# </tr>
#   <tr>
#   <td>Borrowings and Other Liabilities</td>
#   <td>20</td>
#   </tr>
# </table>

# %%
# type your code here

budget_data = { "Income From": ["Corporation Tax", "Income Tax", "Customs", "Union Excise Duties", "GST & Other Taxes", "Non-Tax Revenue", "Non-Debt Capital Receipts", "Borrowings and Other Liabilities"],
               "Amount(in paise)" : [21, 16, 4, 8, 19, 9, 3, 20]
}

budget_dataframe = pd.DataFrame(budget_data)
plt.pie(budget_dataframe['Amount(in paise)'], autopct = '%.1f%%', radius = 1.2, labels = ['Corporation Tax', 'Income Tax','Customs','Union Excise Duties','GST & Other Taxes','Non-Tax Revenue', "Non-Debt Capital Receipts","Borrowings and Other Liabilities"])
# Out:
# ([<matplotlib.patches.Wedge at 0x17fd8e710>,
#   <matplotlib.patches.Wedge at 0x17fd9f810>,
#   <matplotlib.patches.Wedge at 0x17fda9650>,
#   <matplotlib.patches.Wedge at 0x17fda8d10>,
#   <matplotlib.patches.Wedge at 0x17fdb9150>,
#   <matplotlib.patches.Wedge at 0x17fdbb2d0>,
#   <matplotlib.patches.Wedge at 0x17fdc8e10>,
#   <matplotlib.patches.Wedge at 0x17fdcabd0>],
#  [Text(1.0430046330003697, 0.809037289338238, 'Corporation Tax'),
#   Text(-0.3282705840230339, 1.2785297899013446, 'Income Tax'),
#   Text(-1.0170774245319987, 0.8413997340784918, 'Customs'),
#   Text(-1.2553945709571337, 0.40790252660574977, 'Union Excise Duties'),
#   Text(-1.1361795347816015, -0.6719345687962959, 'GST & Other Taxes'),
#   Text(-0.20649360371228273, -1.3037485921855927, 'Non-Tax Revenue'),
#   Text(0.28794898185315876, -1.2882101473943333, 'Non-Debt Capital Receipts'),
#   Text(1.0679023799088951, -0.7758766055146383, 'Borrowings and Other Liabilities')],
#  [Text(0.5689116180002016, 0.4412930669117661, '21.0%'),
#   Text(-0.17905668219438212, 0.6973798854007334, '16.0%'),
#   Text(-0.554769504290181, 0.45894530949735907, '4.0%'),
#   Text(-0.6847606750675275, 0.22249228723949985, '8.0%'),
#   Text(-0.6197342916990553, -0.36650976479797953, '19.0%'),
#   Text(-0.11263287475215421, -0.711135595737596, '9.0%'),
#   Text(0.15706308101081384, -0.702660080396909, '3.0%'),
#   Text(0.5824922072230337, -0.4232054211898027, '20.0%')])

# %% [markdown]
# ### d. Line plots

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 16. Import the 'Returns.csv'. Plot a multiple line plot for the returns of each company
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

returns_dataframe = pd.read_csv("./Dataset/Returns.csv")

returns_dataframe.head()

X = returns_dataframe['Day']
Y1 = returns_dataframe['TCS']
Y2 = returns_dataframe['HDFCBANK']
Y3 = returns_dataframe['JINDALSTEL']
Y4 = returns_dataframe['TATAMOTORS']
Y5 = returns_dataframe['INFY']
Y6 = returns_dataframe['BOSCHLTD']


plt.plot(X,Y1, 'r', Y2, 'b', Y3, 'g', Y4, 'k', Y5, 'm')

plt.xlabel('Day')
plt.ylabel('Returns')
plt.title('Returns for Companies vs Day')

location = 0 
legend_drawn_flag = True
plt.legend(["TCS", "HDFCBANK","JINDALSTEL","TATAMOTORS","INFY","BOSCHLTD"], loc=0, frameon=legend_drawn_flag) 

plt.show()

# %% [markdown]
# <a id='seaborn'></a>
# ## 9. Plots using Library Seaborn

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 17. Import the dataset age_height.csv. Plot a heat map for the correlation matrix
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
age_height_df = pd.read_csv("./Dataset/age_height.csv")

corr_matrix = age_height_df.corr()

sns.heatmap(corr_matrix, annot = True)

plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 18. Plot a  swarmplot using inbuilt data-set 'iris' given in seaborn
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
iris_dataset = sns.load_dataset("iris")

sns.swarmplot(y = 'sepal_length', x = 'sepal_width', data = iris_dataset, hue = 'petal_width' )

plt.show()
# Out:
# /Users/anurag_singh/Desktop/DSBA/jupyter-notebook/pyenv/lib/python3.11/site-packages/seaborn/categorical.py:3370: UserWarning: 11.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 19. Using the 'diamonds' data available in the library seaborn, consider the price for the type of cut. Display the data using the following plots:
#                         <ol>
#                             <li> Multiple boxplot</li>
#                             <li> Violin Plot </li>
#                             <li> Boxen Plot </li>
#                         </ol>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

#Multiplt BoxPlot
diamonds = sns.load_dataset("diamonds")

sns.boxplot(x='cut', y='price', data=diamonds)
plt.xlabel('cut')
plt.ylabel('price')
plt.title('Diamond cut vs price')
plt.show()

# %%
#Violin Plot
sns.violinplot(y = 'price', x = 'cut', data = diamonds)
plt.title('Diamond cut vs price')
plt.show()

# %%
#Boxen Plot
sns.boxenplot(y = 'price', x = 'cut', data = diamonds)
plt.title('Diamond cut vs price')
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 20. Generate random number form normal distribution, plot the following:
#                         <ol>
#                             <li> Histogram</li>
#                             <li> Histogram with frequency curve </li>
#                         </ol>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
#Histogram of random numbers from normal distribution

random_numbers = np.random.normal(loc=0, scale=1, size=1000)

plt.hist(random_numbers, bins=20, density=True, alpha=0.9, color='green')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Random Numbers from Normal Distribution')
plt.grid(True)
plt.show()

# %%
#Histogram with frequency curve
random_numbers = np.random.normal(loc=0, scale=1, size=1000)

plt.figure(figsize=(8, 6))
plt.hist(random_numbers, bins=30, density=True, alpha=0.7, color='green', label='Histogram')


xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
frequency = (1 / (np.sqrt(2 * np.pi) * 1)) * np.exp(-0.5 * ((x - 0) / 1) ** 2)  # PDF for normal distribution
plt.plot(x, frequency, label='Frequency Curve', color='red')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram with Frequency Curve for Random Numbers from Normal Distribution')
plt.legend()
plt.grid(True)
plt.show()
