# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# Avoids multiple plt.show() calls
# %matplotlib inline

# %%
auto = pd.read_csv('./Dataset/Automobile.csv')

# %%
auto.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
auto.shape
# Out:
# (201, 26)

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symboling            201 non-null    int64
#  1   normalized_losses    201 non-null    int64
#  2   make                 201 non-null    object
#  3   fuel_type            201 non-null    object
#  4   aspiration           201 non-null    object
#  5   number_of_doors      201 non-null    object
#  6   body_style           201 non-null    object
#  7   drive_wheels         201 non-null    object
#  8   engine_location      201 non-null    object
#  9   wheel_base           201 non-null    float64
#  10  length               201 non-null    float64
#  11  width                201 non-null    float64
#  12  height               201 non-null    float64
#  13  curb_weight          201 non-null    int64
#  14  engine_type          201 non-null    object
# ...

# %%
auto.describe().T
# Out:
#                    count          mean          std      min      25%  \
# symboling          201.0      0.840796     1.254802    -2.00     0.00
# normalized_losses  201.0    125.189055    33.572966    65.00   101.00
# wheel_base         201.0     98.797015     6.066366    86.60    94.50
# length             201.0    174.200995    12.322175   141.10   166.80
# width              201.0     65.889055     2.101471    60.30    64.10
# height             201.0     53.766667     2.447822    47.80    52.00
# curb_weight        201.0   2555.666667   517.296727  1488.00  2169.00
# engine_size        201.0    126.875622    41.546834    61.00    98.00
# bore               201.0      3.329701     0.268166     2.54     3.15
# stroke             201.0      3.261741     0.317875     2.07     3.11
# compression_ratio  201.0     10.164279     4.004965     7.00     8.60
# horsepower         201.0    103.263682    37.389372    48.00    70.00
# ...

# %%
# Univariate Visualization (Analyzing distribution of data for a single variable)
# Shows the frequency of single numerical variable 
sns.histplot(data=auto, x='price')
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
#Changing the default Bin size
sns.histplot(data=auto, x='price', bins=5, color='magenta')
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
#Histogram with Kernel Density Estimation
sns.histplot(data=auto, x='price', kde=True, bins=5, color='orange')
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.histplot(data=auto, x='curb_weight', kde=True, color='green')
# Out:
# <Axes: xlabel='curb_weight', ylabel='Count'>

# %%
#Bivariate Analysis
sns.histplot(data=auto, x='price', hue='body_style', kde=True, color='cyan')
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
g = sns.FacetGrid(auto, col="body_style")
g.map(sns.histplot, "price");

# %%
# Shows where is the density is centered
sns.displot(auto['wheel_base'], kde = True, rug= True)
plt.show()

# %%
# Univariate Visualization (Analyzing distribution of data for a single variable)

# displot() only supports numerical variable not categorical variable
sns.displot(auto['engine_size'])
plt.show()

# %%
#Bivariate Visualization 
#Analyzing distribution of data for a two numerical variable
joint_plot = sns.jointplot(x=auto['engine_size'], y=auto['horsepower'])
plt.show()

# %%
sns.jointplot(x=auto['engine_size'], y=auto['horsepower'], kind="hex")
plt.show()

# %%
sns.jointplot(x=auto['engine_size'], y=auto['horsepower'], kind="kde")
plt.show()

# %%
# Multivariate Visualization
sns.pairplot(auto[['wheel_base','engine_size', 'horsepower']])

# %%
# Visualization of a Categorical Variable with Numerical Variable
# Contains lots of overlapping dots without jitter not very useful
sns.stripplot(x=auto['fuel_type'], y=auto['horsepower'] , jitter=False)
# Out:
# <Axes: xlabel='fuel_type', ylabel='horsepower'>

# %%
# Visualization of a Categorical Variable with Numerical Variable
# Randomly splitted dots in Jitter
sns.stripplot(x=auto['fuel_type'], y=auto['horsepower'])
# Out:
# <Axes: xlabel='fuel_type', ylabel='horsepower'>

# %%
# More Cleaner Visualization compared to Stripplot
# Ordered splitted dots 
sns.swarmplot(x=auto['fuel_type'], y=auto['horsepower'] )
# Out:
# <Axes: xlabel='fuel_type', ylabel='horsepower'>

# %%
sns.boxplot(x=auto['fuel_type'], y=auto['horsepower'], hue = auto['drive_wheels'] )
# Out:
# <Axes: xlabel='fuel_type', ylabel='horsepower'>

# %%
# Boxplot tells the distribution of data in comparison normal distribution
# Right Skew  known as Positive Skew
# Left skew known as Negative Skew
sns.boxplot(data=auto, x ='curb_weight')
# Out:
# <Axes: xlabel='curb_weight'>

# %%
sns.boxplot(x=auto['body_style'], y=auto['price'])
# Out:
# <Axes: xlabel='body_style', ylabel='price'>

# %%
sns.boxplot(x=auto['num-of-doors'], y=auto['horsepower'], hue = auto['fuel-type'])
# Out:
# <Axes: xlabel='num-of-doors', ylabel='horsepower'>

# %%
#Lines of top are confidence interval for the distribution of interval
sns.barplot(x=auto['body-style'], y=auto['horsepower'], hue = auto['engine-location'] )
# Out:
# <Axes: xlabel='body-style', ylabel='horsepower'>

# %% [markdown]
# Continous Variable
# Example: height like 1.68451.....
#
#
# Discrete Variable (Whole Numbers)
# Example: No.of members in family
#
# Categorical variable
# Non numerical values

# %%
sns.countplot(x=auto['body_style'] )
# Out:
# <Axes: xlabel='body_style', ylabel='count'>

# %%
plt.figure(figsize=(20,7))
sns.countplot(data=auto, x='make')
plt.xticks(rotation=45)
plt.show()

# %%
#Shows the frequency of categorical variable on y-axis
sns.countplot(x=auto['body_style'], hue = auto['engine_location'] )
# Out:
# <Axes: xlabel='body_style', ylabel='count'>

# %%
flights = sns.load_dataset("flights")

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
#background top and bottom lines show confidence interval ranges
sns.lineplot(data = flights, x='month', y='passengers')
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %% [markdown]
# Confidence Interval range of time to complete the swim from A to B
# At anyday 95% confidence level we can say the swimmer can same distance.
#
# If the confidence level is increased to 99% that increases the confidence interval range.
#
# Industry norm/Thumb Rule is 95% confidence level.

# %%
#Get rid of ci
sns.lineplot(data = flights, x='month', y='passengers', ci=False)
# Out:
# /var/folders/ts/t0y8j7tn61v2qmfqjwmswtmm0000gn/T/ipykernel_6351/3967268547.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data = flights, x='month', y='passengers', ci=False)
# <Axes: xlabel='month', ylabel='passengers'>

# %%
sns.lineplot(data = flights, x='month', y='passengers', ci=False, hue='year')
# Out:
# /var/folders/ts/t0y8j7tn61v2qmfqjwmswtmm0000gn/T/ipykernel_6351/444687148.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data = flights, x='month', y='passengers', ci=False, hue='year')
# <Axes: xlabel='month', ylabel='passengers'>

# %%
#Sactter Plot
sns.scatterplot(data = auto, x='engine_size', y='price')
# Out:
# <Axes: xlabel='engine_size', ylabel='price'>

# %%
#Sactter Plot
sns.scatterplot(data = auto, x='engine_size', y='price', hue='fuel_type')
# Out:
# <Axes: xlabel='engine_size', ylabel='price'>

# %%
sns.scatterplot(data = auto, x='engine_size', y='price', hue='fuel_type', style='fuel_type')
# Out:
# <Axes: xlabel='engine_size', ylabel='price'>

# %%
sns.pointplot(x=auto['body_style'], y=auto['horsepower'], hue = auto['number_of_doors'])
# Out:
# <Axes: xlabel='body_style', ylabel='horsepower'>

# %%
sns.catplot(x="fuel_type", 
               y="horsepower",
               hue="body_style",
               col="engine_location",
               data=auto,
               kind="violin")

# %%
sns.lmplot(data=auto, x='curb_weight', y='horsepower')

# %%
sns.lmplot(data=auto, x='curb_weight', y='horsepower', hue='fuel_type')

# %%
#Multiplots with lmplot
sns.lmplot(data=auto, x='curb_weight', y='horsepower', col='fuel_type')

# %%
auto = auto.dropna(subset=['horsepower', 'peak_rpm'])

# Plot the Linear Regression Plot via lmplot after handling missing or non-numeric values
sns.lmplot(x="horsepower", y="peak_rpm", data=auto, hue="fuel_type")

# %%
#Multivariate Analysis
sns.catplot(data=auto, x="fuel_type", y="horsepower", hue="number_of_doors", col='drive_wheels', kind='bar')

# %%
sns.jointplot(data=auto, x="engine_size", y="horsepower")

# %%
sns.jointplot(data=auto, x="engine_size", y="horsepower", kind='hex')
plt.colorbar();

# %%
sns.jointplot(data=auto, x="engine_size", y="city_mpg", kind="reg")

# %%
sns.violinplot(data=auto,  x="horsepower")
# Out:
# <Axes: xlabel='horsepower'>

# %%
sns.violinplot(data=auto,  x="fuel_type", y="horsepower", hue='number_of_doors')
plt.show()

# %%
sns.stripplot(data=auto, x="engine_size")
# Out:
# <Axes: xlabel='engine_size'>
